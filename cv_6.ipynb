# %% [markdown]
# <a href="https://colab.research.google.com/github/battalamadhuri273-commits/cv-lab/blob/main/cv_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import cv2

# %%
rmin=100
rmax=200

# %%
img=cv2.imread("/content/drive/MyDrive/img_10",0)

# %%
slicing_with_bg=img.copy()
slicing_without_bg=np.zeros(img.shape, dtype=np.uint8)
for i in range(img.shape[0]):
  for j in range(img.shape[1]):
    pixel_value=img[i][j]
    if rmin <= np.mean(pixel_value) <= rmax:
      slicing_with_bg[i][j]=255
      slicing_without_bg[i][j]=255
    else:
      slicing_without_bg[i][j]=0
# The 'show' function is not defined in this context. You might want to use matplotlib.pyplot.imshow or cv2.imshow.
# For example, using matplotlib:
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
plt.imshow(img,cmap='gray')
plt.title("Original grayscale image")
plt.figure(figsize=(6, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(slicing_with_bg, cv2.COLOR_BGR2RGB))
plt.title('Slice With Background')
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(slicing_without_bg, cv2.COLOR_BGR2RGB))
plt.title('Slice Without Background')
plt.show()
